# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
# Constants
EXP_DATA_DIR = "E:\\IITP\\Academics\\7th Semester 26 Jul'23 - 1 Dec'23\\BTP\\Experiment Data\\Plots"
THR_DATA_DIR = "E:\\IITP\\Academics\\7th Semester 26 Jul'23 - 1 Dec'23\\BTP\\TheoreticalPlotImages"
PHM_Test_1_B3_DIR = "E:\\IITP\\Academics\\7th Semester 26 Jul'23 - 1 Dec'23\\BTP\\PHM Society Bearings Data\\test 1 plot images\\Bearing 3"
PHM_Test_1_B4_DIR = "E:\\IITP\\Academics\\7th Semester 26 Jul'23 - 1 Dec'23\\BTP\\PHM Society Bearings Data\\test 1 plot images\\Bearing 4"
IMAGE_SIZE = (100, 100)

# Lists to store data
exp_data_list = []
thr_data_list = []
phm_t1b3_data_list = []
phm_t1b4_data_list = []

# Dictionary to map the axis to a one-hot encoded list
axis_map = {
    "X": [1, 0, 0],
    "Y": [0, 1, 0],
    "Z": [0, 0, 1]
}

# %%
# Iterate over files to populate the list
for filename in os.listdir(THR_DATA_DIR):
    if filename.endswith(".png") and any(axis in filename for axis in ["X", "Y"]):

        # Split filename to extract details
        parts = filename.split("_")
        status = parts[0]
        hz = int(parts[1].split("-")[0].replace("Hz", ""))
        axis = filename.split("-")[1]

        # Set label based on status
        label = 1 if status == "faulty" else 0

        # Read and resize the image using TensorFlow
        path = os.path.join(THR_DATA_DIR, filename)
        image = tf.io.read_file(path)
        image = tf.image.decode_png(image, channels=1)  # Decoding to grayscale
        image = tf.image.resize(image, IMAGE_SIZE)
        image = tf.squeeze(image).numpy()  # Convert tensor to numpy array

        # Append to the data list
        thr_data_list.append([image, hz, label, axis_map[axis]])

# %%
# Iterate over files to populate the list
for filename in os.listdir(PHM_Test_1_B3_DIR):
    if filename.endswith(".png"):

        # Split filename to extract details
#         parts = filename.split("_")
#         status = parts[0]
        hz = 33
        axis = "X"

        # Set label based on status
        label = 0

        # Read and resize the image using TensorFlow
        path = os.path.join(PHM_Test_1_B3_DIR, filename)
        image = tf.io.read_file(path)
        image = tf.image.decode_png(image, channels=1)  # Decoding to grayscale
        image = tf.image.resize(image, IMAGE_SIZE)
        image = tf.squeeze(image).numpy()  # Convert tensor to numpy array

        # Append to the data list
        phm_t1b3_data_list.append([image, hz, label, axis_map[axis]])

# %%
# Iterate over files to populate the list
for filename in os.listdir(PHM_Test_1_B4_DIR):
    if filename.endswith(".png"):

        # Split filename to extract details
#         parts = filename.split("_")
#         status = parts[0]
        hz = 33
        axis = "X"

        # Set label based on status
        label = 0

        # Read and resize the image using TensorFlow
        path = os.path.join(PHM_Test_1_B4_DIR, filename)
        image = tf.io.read_file(path)
        image = tf.image.decode_png(image, channels=1)  # Decoding to grayscale
        image = tf.image.resize(image, IMAGE_SIZE)
        image = tf.squeeze(image).numpy()  # Convert tensor to numpy array

        # Append to the data list
        phm_t1b4_data_list.append([image, hz, label, axis_map[axis]])

# %%
# # Iterate over files to populate the list
# for filename in os.listdir(EXP_DATA_DIR):
#     if filename.endswith(".png") and any(axis in filename for axis in ["X", "Y"]):

#         # Split filename to extract details
#         parts = filename.split("_")
#         status = parts[0]
#         hz = int(parts[1].split("-")[0].replace("Hz", ""))
#         axis = filename.split("-")[1]

#         # Set label based on status
#         label = 1 if status == "Faulty" else 0

#         # Read and resize the image using TensorFlow
#         path = os.path.join(EXP_DATA_DIR, filename)
#         image = tf.io.read_file(path)
#         image = tf.image.decode_png(image, channels=1)  # Decoding to grayscale
#         image = tf.image.resize(image, IMAGE_SIZE)
#         image = tf.squeeze(image).numpy()  # Convert tensor to numpy array

#         # Append to the data list
#         exp_data_list.append([image, hz, label, axis_map[axis]])

# %%
print('Theoretical Data Plots')
# Generate 16 random indices from test_list
random_indices = np.random.choice(len(thr_data_list), 16, replace=False)

fig, axes = plt.subplots(4, 4, figsize=(8, 8))

for i, ax in enumerate(axes.flat):
    current_sample = thr_data_list[random_indices[i]]
    image, frequency, label, _ = current_sample

    ax.imshow(image, cmap="gray")
    ax.set_title(f"Frequency: {frequency} Hz\nLabel: {label}", fontsize=8)
    
    # Remove axis ticks
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Theoretical Data Plots

# %%
# print('Experimental Data Plots')
# # Generate 16 random indices from test_list
# random_indices = np.random.choice(len(exp_data_list), 16, replace=False)

# fig, axes = plt.subplots(4, 4, figsize=(8, 8))

# for i, ax in enumerate(axes.flat):
#     current_sample = exp_data_list[random_indices[i]]
#     image, frequency, label, _ = current_sample

#     ax.imshow(image, cmap="gray")
#     ax.set_title(f"Frequency: {frequency} Hz\nLabel: {label}", fontsize=8)
    
#     # Remove axis ticks
#     ax.axis('off')

# plt.tight_layout()
# plt.show()

# %%
# Convert the data list to separate numpy arrays
thr_images = np.array([item[0] for item in thr_data_list])
thr_frequencies = np.array([item[1] for item in thr_data_list], dtype=np.int)
thr_labels = np.array([item[2] for item in thr_data_list], dtype=np.int)
thr_axes = np.array([item[3] for item in thr_data_list], dtype=np.int)

print('Theoretical Data Shapes')
print(thr_images.shape)
print(thr_frequencies.shape)
print(thr_labels.shape)
print(thr_axes.shape)
# Out:
# Theoretical Data Shapes
# (1064, 100, 100)
# (1064,)
# (1064,)
# (1064, 3)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\648198210.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   thr_frequencies = np.array([item[1] for item in thr_data_list], dtype=np.int)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\648198210.py:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   thr_labels = np.array([item[2] for item in thr_data_list], dtype=np.int)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\648198210.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   thr_axes = np.array([item[3] for item in thr_data_list], dtype=np.int)

# %%
# Convert the data list to separate numpy arrays
phm_t1b3_images = np.array([item[0] for item in phm_t1b3_data_list])
phm_t1b3_frequencies = np.array([item[1] for item in phm_t1b3_data_list], dtype=np.int)
phm_t1b3_labels = np.array([item[2] for item in phm_t1b3_data_list], dtype=np.int)
phm_t1b3_axes = np.array([item[3] for item in phm_t1b3_data_list], dtype=np.int)

print('PHM Test 1 Bearing 3 Data Shapes')
print(phm_t1b3_images.shape)
print(phm_t1b3_frequencies.shape)
print(phm_t1b3_labels.shape)
print(phm_t1b3_axes.shape)
# Out:
# PHM Test 1 Bearing 3 Data Shapes
# (2156, 100, 100)
# (2156,)
# (2156,)
# (2156, 3)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\77271913.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   phm_t1b3_frequencies = np.array([item[1] for item in phm_t1b3_data_list], dtype=np.int)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\77271913.py:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   phm_t1b3_labels = np.array([item[2] for item in phm_t1b3_data_list], dtype=np.int)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\77271913.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   phm_t1b3_axes = np.array([item[3] for item in phm_t1b3_data_list], dtype=np.int)

# %%
# Convert the data list to separate numpy arrays
phm_t1b4_images = np.array([item[0] for item in phm_t1b4_data_list])
phm_t1b4_frequencies = np.array([item[1] for item in phm_t1b4_data_list], dtype=np.int)
phm_t1b4_labels = np.array([item[2] for item in phm_t1b4_data_list], dtype=np.int)
phm_t1b4_axes = np.array([item[3] for item in phm_t1b4_data_list], dtype=np.int)

print('PHM Test 1 Bearing 4 Data Shapes')
print(phm_t1b4_images.shape)
print(phm_t1b4_frequencies.shape)
print(phm_t1b4_labels.shape)
print(phm_t1b4_axes.shape)
# Out:
# PHM Test 1 Bearing 4 Data Shapes
# (2156, 100, 100)
# (2156,)
# (2156,)
# (2156, 3)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\726397927.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   phm_t1b4_frequencies = np.array([item[1] for item in phm_t1b4_data_list], dtype=np.int)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\726397927.py:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   phm_t1b4_labels = np.array([item[2] for item in phm_t1b4_data_list], dtype=np.int)
# C:\Users\Rudrransh\AppData\Local\Temp\ipykernel_17604\726397927.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   phm_t1b4_axes = np.array([item[3] for item in phm_t1b4_data_list], dtype=np.int)

# %%
# # Convert the data list to separate numpy arrays
# exp_images = np.array([item[0] for item in exp_data_list])
# exp_frequencies = np.array([item[1] for item in exp_data_list], dtype=np.int)
# exp_labels = np.array([item[2] for item in exp_data_list], dtype=np.int)
# exp_axes = np.array([item[3] for item in exp_data_list], dtype=np.int)

# print('Experimental Data Shapes')
# print(exp_images.shape)
# print(exp_frequencies.shape)
# print(exp_labels.shape)
# print(exp_axes.shape)

# %%
X_thr = [thr_images, thr_frequencies, thr_axes]
y_thr = thr_labels
# X_exp = [exp_images, exp_frequencies, exp_axes]
# y_exp = exp_labels

X_train = X_thr
y_train = y_thr
X_test_b3 = [phm_t1b3_images, phm_t1b3_frequencies, phm_t1b3_axes]
X_test_b4 = [phm_t1b4_images, phm_t1b4_frequencies, phm_t1b4_axes]

# %%
# CNN for the image input
image_input = layers.Input(shape=(100, 100, 1), name='image_input')
x = layers.Conv2D(128, (3, 3), activation='relu')(image_input)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Flatten()(x)
image_output = layers.Dense(32, activation='relu')(x)

# DNN for the frequency input
frequency_input = layers.Input(shape=(1,), name='frequency_input')
y = layers.Dense(32, activation='relu')(frequency_input)
frequency_output = layers.Dense(32, activation='relu')(y)

# DNN for the axis input
axis_input = layers.Input(shape=(3,), name='axis_input')
z = layers.Dense(32, activation='relu')(axis_input)
axis_output = layers.Dense(32, activation='relu')(z)

# Concatenate the outputs of all branches
combined = layers.concatenate([image_output, frequency_output, axis_output])
w = layers.Dense(32, activation='relu')(combined)
w = layers.Dense(16, activation='relu')(w)

# Output layer
output = layers.Dense(1, activation='sigmoid')(w)

model = Model(inputs=[image_input, frequency_input, axis_input], outputs=output)

# %%
# from tensorflow.keras.utils import plot_model
# plot_model(model, to_file='model_flowchart.png', show_shapes=False, show_layer_names=True, dpi=1200)

# %%
# Define the optimizer with custom learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model using the custom optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'])

history = model.fit(X_train, y_train, epochs=10, shuffle = True)
# Out:
# Epoch 1/10
# 34/34 [==============================] - 25s 698ms/step - loss: 1.6474 - binary_accuracy: 0.6212
# Epoch 2/10
# 34/34 [==============================] - 24s 690ms/step - loss: 0.1908 - binary_accuracy: 0.9333
# Epoch 3/10
# 34/34 [==============================] - 24s 703ms/step - loss: 0.0071 - binary_accuracy: 1.0000
# Epoch 4/10
# 34/34 [==============================] - 26s 749ms/step - loss: 0.0028 - binary_accuracy: 1.0000
# Epoch 5/10
# 34/34 [==============================] - 23s 684ms/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 6/10
# 34/34 [==============================] - 23s 686ms/step - loss: 9.8499e-04 - binary_accuracy: 1.0000
# Epoch 7/10
# 34/34 [==============================] - 23s 687ms/step - loss: 6.6166e-04 - binary_accuracy: 1.0000
# Epoch 8/10
# 34/34 [==============================] - 24s 706ms/step - loss: 6.0516e-04 - binary_accuracy: 1.0000
# Epoch 9/10
# 34/34 [==============================] - 24s 707ms/step - loss: 4.9690e-04 - binary_accuracy: 1.0000
# Epoch 10/10
# 34/34 [==============================] - 24s 700ms/step - loss: 4.3049e-04 - binary_accuracy: 1.0000

# %%
# Visualize the training history
plt.figure(figsize=(8, 3))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['binary_accuracy'], label='Train Accuracy')
# plt.plot(history.history['val_binary_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.tight_layout()
plt.show()

# %%
X_new_b3 = []

# Iterate over each array in X_test_b3
for arr in X_test_b3:
    # Select the first 5 and last 5 elements
    selected_elements = np.concatenate((arr[:10], arr[-10:]))
    # Append the selected elements to X_new
    X_new_b3.append(selected_elements)

# Convert the list to numpy array
# X_new = np.array(X_new)
    
X_new_b4 = []

# Iterate over each array in X_test_b3
for arr in X_test_b4:
    # Select the first 5 and last 5 elements
    selected_elements = np.concatenate((arr[:10], arr[-10:]))
    # Append the selected elements to X_new
    X_new_b4.append(selected_elements)

# Convert the list to numpy array
# X_new = np.array(X_new)

# %%
y_new_b3 = []
labels = np.concatenate((np.zeros(10), np.ones(10)))
# Append the labels to y_new
y_new_b3.append(labels)

y_new_b4 = []
labels = np.concatenate((np.zeros(10), np.ones(10)))
# Append the labels to y_new
y_new_b4.append(labels)

# %%
# Assuming X_new is a list containing three lists, and the first list contains images
first_images = X_new_b3[0]  # Select the first list containing images

# Plot each image in the first list
plt.figure(figsize=(15, 5))
for i, image in enumerate(first_images):
    plt.subplot(1, len(first_images), i + 1)
    plt.imshow(image, cmap='gray')  # Assuming grayscale images
    plt.title(f'{i+1}')
    plt.axis('off')

# plt.title('Images in the First List', fontsize=16)
plt.show()

# %%
# Assuming X_new is a list containing three lists, and the first list contains images
first_images = X_new_b4[0]  # Select the first list containing images

# Plot each image in the first list
plt.figure(figsize=(15, 5))
for i, image in enumerate(first_images):
    plt.subplot(1, len(first_images), i + 1)
    plt.imshow(image, cmap='gray')  # Assuming grayscale images
    plt.title(f'{i+1}')
    plt.axis('off')

# plt.title('Images in the First List', fontsize=16)
plt.show()

# %%
# # Freeze all layers except the last one
# for layer in model.layers[3:-2]:
#     layer.trainable = False

# # Print layer dimension, type, and trainable status
# for i, layer in enumerate(model.layers):
#     print(f'Layer {i}: Name = {layer.name}, Output Shape = {layer.output_shape}, Trainable = {layer.trainable}')

# %%
# Concatenating corresponding lists from X_new_b3 and X_new_b4
X_new = [b3 + b4 for b3, b4 in zip(X_new_b3, X_new_b4)]
y_new = y_new_b3 + y_new_b4

# Compile the model
# model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'])

# Assuming X_new and y_new are your new dataset features and labels
# Fit the model on new data
model.fit(X_new, y_new, epochs=70, shuffle = True)
# Out:
# Epoch 1/70
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0051 - binary_accuracy: 1.0000
# Epoch 2/70
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0042 - binary_accuracy: 1.0000
# Epoch 3/70
# 1/1 [==============================] - 1s 511ms/step - loss: 0.0034 - binary_accuracy: 1.0000
# Epoch 4/70
# 1/1 [==============================] - 1s 602ms/step - loss: 0.0023 - binary_accuracy: 1.0000
# Epoch 5/70
# 1/1 [==============================] - 1s 535ms/step - loss: 0.0013 - binary_accuracy: 1.0000
# Epoch 6/70
# 1/1 [==============================] - 0s 494ms/step - loss: 6.0289e-04 - binary_accuracy: 1.0000
# Epoch 7/70
# 1/1 [==============================] - 0s 485ms/step - loss: 2.7044e-04 - binary_accuracy: 1.0000
# Epoch 8/70
# 1/1 [==============================] - 1s 531ms/step - loss: 1.6099e-04 - binary_accuracy: 1.0000
# Epoch 9/70
# 1/1 [==============================] - 1s 598ms/step - loss: 1.3810e-04 - binary_accuracy: 1.0000
# Epoch 10/70
# 1/1 [==============================] - 1s 791ms/step - loss: 1.3649e-04 - binary_accuracy: 1.0000
# Epoch 11/70
# 1/1 [==============================] - 1s 648ms/step - loss: 1.3810e-04 - binary_accuracy: 1.0000
# Epoch 12/70
# 1/1 [==============================] - 1s 598ms/step - loss: 1.2685e-04 - binary_accuracy: 1.0000
# Epoch 13/70
# 1/1 [==============================] - 1s 523ms/step - loss: 1.0042e-04 - binary_accuracy: 1.0000
# Epoch 14/70
# 1/1 [==============================] - 1s 587ms/step - loss: 6.6374e-05 - binary_accuracy: 1.0000
# Epoch 15/70
# 1/1 [==============================] - 1s 585ms/step - loss: 3.8788e-05 - binary_accuracy: 1.0000
# Epoch 16/70
# 1/1 [==============================] - 1s 598ms/step - loss: 2.3838e-05 - binary_accuracy: 1.0000
# Epoch 17/70
# 1/1 [==============================] - 1s 737ms/step - loss: 1.8476e-05 - binary_accuracy: 1.0000
# Epoch 18/70
# 1/1 [==============================] - 1s 512ms/step - loss: 1.8683e-05 - binary_accuracy: 1.0000
# Epoch 19/70
# 1/1 [==============================] - 0s 482ms/step - loss: 2.1730e-05 - binary_accuracy: 1.0000
# Epoch 20/70
# 1/1 [==============================] - 0s 435ms/step - loss: 2.4539e-05 - binary_accuracy: 1.0000
# Epoch 21/70
# 1/1 [==============================] - 0s 449ms/step - loss: 2.4853e-05 - binary_accuracy: 1.0000
# Epoch 22/70
# 1/1 [==============================] - 0s 434ms/step - loss: 2.2217e-05 - binary_accuracy: 1.0000
# Epoch 23/70
# 1/1 [==============================] - 0s 435ms/step - loss: 1.7899e-05 - binary_accuracy: 1.0000
# Epoch 24/70
# 1/1 [==============================] - 0s 454ms/step - loss: 1.3352e-05 - binary_accuracy: 1.0000
# Epoch 25/70
# 1/1 [==============================] - 0s 443ms/step - loss: 9.5390e-06 - binary_accuracy: 1.0000
# Epoch 26/70
# 1/1 [==============================] - 0s 447ms/step - loss: 6.7543e-06 - binary_accuracy: 1.0000
# Epoch 27/70
# 1/1 [==============================] - 0s 443ms/step - loss: 4.8552e-06 - binary_accuracy: 1.0000
# Epoch 28/70
# 1/1 [==============================] - 0s 471ms/step - loss: 3.6271e-06 - binary_accuracy: 1.0000
# Epoch 29/70
# 1/1 [==============================] - 0s 485ms/step - loss: 2.8741e-06 - binary_accuracy: 1.0000
# Epoch 30/70
# 1/1 [==============================] - 0s 471ms/step - loss: 2.5189e-06 - binary_accuracy: 1.0000
# Epoch 31/70
# 1/1 [==============================] - 0s 466ms/step - loss: 2.2855e-06 - binary_accuracy: 1.0000
# Epoch 32/70
# 1/1 [==============================] - 0s 453ms/step - loss: 2.1119e-06 - binary_accuracy: 1.0000
# Epoch 33/70
# 1/1 [==============================] - 0s 437ms/step - loss: 1.9862e-06 - binary_accuracy: 1.0000
# Epoch 34/70
# 1/1 [==============================] - 0s 479ms/step - loss: 1.8934e-06 - binary_accuracy: 1.0000
# Epoch 35/70
# 1/1 [==============================] - 1s 506ms/step - loss: 1.8254e-06 - binary_accuracy: 1.0000
# Epoch 36/70
# 1/1 [==============================] - 0s 443ms/step - loss: 1.7781e-06 - binary_accuracy: 1.0000
# Epoch 37/70
# 1/1 [==============================] - 0s 444ms/step - loss: 1.7625e-06 - binary_accuracy: 1.0000
# Epoch 38/70
# 1/1 [==============================] - 0s 456ms/step - loss: 1.7596e-06 - binary_accuracy: 1.0000
# Epoch 39/70
# 1/1 [==============================] - 0s 436ms/step - loss: 1.7542e-06 - binary_accuracy: 1.0000
# Epoch 40/70
# 1/1 [==============================] - 0s 435ms/step - loss: 1.7465e-06 - binary_accuracy: 1.0000
# Epoch 41/70
# 1/1 [==============================] - 0s 465ms/step - loss: 1.7340e-06 - binary_accuracy: 1.0000
# Epoch 42/70
# 1/1 [==============================] - 0s 453ms/step - loss: 1.7158e-06 - binary_accuracy: 1.0000
# Epoch 43/70
# 1/1 [==============================] - 0s 447ms/step - loss: 1.6921e-06 - binary_accuracy: 1.0000
# Epoch 44/70
# 1/1 [==============================] - 1s 516ms/step - loss: 1.6632e-06 - binary_accuracy: 1.0000
# Epoch 45/70
# 1/1 [==============================] - 1s 584ms/step - loss: 1.6298e-06 - binary_accuracy: 1.0000
# Epoch 46/70
# 1/1 [==============================] - 1s 592ms/step - loss: 1.5927e-06 - binary_accuracy: 1.0000
# Epoch 47/70
# 1/1 [==============================] - 1s 563ms/step - loss: 1.5528e-06 - binary_accuracy: 1.0000
# Epoch 48/70
# 1/1 [==============================] - 1s 574ms/step - loss: 1.5111e-06 - binary_accuracy: 1.0000
# Epoch 49/70
# 1/1 [==============================] - 1s 590ms/step - loss: 1.4683e-06 - binary_accuracy: 1.0000
# Epoch 50/70
# 1/1 [==============================] - 1s 581ms/step - loss: 1.4252e-06 - binary_accuracy: 1.0000
# Epoch 51/70
# 1/1 [==============================] - 1s 585ms/step - loss: 1.3826e-06 - binary_accuracy: 1.0000
# Epoch 52/70
# 1/1 [==============================] - 1s 568ms/step - loss: 1.3420e-06 - binary_accuracy: 1.0000
# Epoch 53/70
# 1/1 [==============================] - 1s 574ms/step - loss: 1.3026e-06 - binary_accuracy: 1.0000
# Epoch 54/70
# 1/1 [==============================] - 1s 589ms/step - loss: 1.2646e-06 - binary_accuracy: 1.0000
# Epoch 55/70
# 1/1 [==============================] - 1s 569ms/step - loss: 1.2283e-06 - binary_accuracy: 1.0000
# Epoch 56/70
# 1/1 [==============================] - 1s 581ms/step - loss: 1.1936e-06 - binary_accuracy: 1.0000
# Epoch 57/70
# 1/1 [==============================] - 1s 684ms/step - loss: 1.1607e-06 - binary_accuracy: 1.0000
# Epoch 58/70
# 1/1 [==============================] - 1s 533ms/step - loss: 1.1295e-06 - binary_accuracy: 1.0000
# Epoch 59/70
# 1/1 [==============================] - 1s 554ms/step - loss: 1.1001e-06 - binary_accuracy: 1.0000
# Epoch 60/70
# 1/1 [==============================] - 1s 552ms/step - loss: 1.0722e-06 - binary_accuracy: 1.0000
# Epoch 61/70
# 1/1 [==============================] - 1s 562ms/step - loss: 1.0458e-06 - binary_accuracy: 1.0000
# Epoch 62/70
# 1/1 [==============================] - 1s 566ms/step - loss: 1.0208e-06 - binary_accuracy: 1.0000
# Epoch 63/70
# 1/1 [==============================] - 1s 567ms/step - loss: 9.9754e-07 - binary_accuracy: 1.0000
# Epoch 64/70
# 1/1 [==============================] - 1s 567ms/step - loss: 9.7587e-07 - binary_accuracy: 1.0000
# Epoch 65/70
# 1/1 [==============================] - 1s 564ms/step - loss: 9.5536e-07 - binary_accuracy: 1.0000
# Epoch 66/70
# 1/1 [==============================] - 1s 571ms/step - loss: 9.3592e-07 - binary_accuracy: 1.0000
# Epoch 67/70
# 1/1 [==============================] - 1s 699ms/step - loss: 9.1743e-07 - binary_accuracy: 1.0000
# Epoch 68/70
# 1/1 [==============================] - 1s 550ms/step - loss: 8.9983e-07 - binary_accuracy: 1.0000
# Epoch 69/70
# 1/1 [==============================] - 1s 576ms/step - loss: 8.8304e-07 - binary_accuracy: 1.0000
# Epoch 70/70
# 1/1 [==============================] - 1s 555ms/step - loss: 8.6698e-07 - binary_accuracy: 1.0000

# %%
# Predict classes
y_pred_probs = model.predict(X_test_b3)
# Out:
# 68/68 [==============================] - 14s 206ms/step

# %%
# Create a list of sample indices from 0 to the end
index = list(range(len(y_pred_probs)))

# Set the size of the plot
plt.figure(figsize=(12, 6))

# Plot the predicted probabilities
plt.plot(index, y_pred_probs)
plt.xlabel('10 Minute Intervals', fontname='Times New Roman', fontsize=12)
plt.ylabel('Predicted Probability', fontname='Times New Roman', fontsize=12)
# plt.title('Predicted Probabilities for Test 1 Bearing 3', fontname='Times New Roman', fontsize=12)
plt.xticks(fontname='Times New Roman', fontsize=12)
plt.yticks(fontname='Times New Roman', fontsize=12)
plt.savefig('Test_1_Bearing_3_Probs.png', format='png', dpi = 600)
plt.show()
# y_pred_classes = (y_pred_probs > 0.5).astype(int).flatten()

# # Generate classification report
# report = classification_report(y_test, y_pred_classes)

# print(report)# Predict classes

# %%
i=2000

# Slice the predicted probabilities from the 600th sample to the end
y_pred_probs_slice = y_pred_probs[i:]

# Create a list of sample indices from 600 to the end
sample_indices = list(range(i, len(y_pred_probs)))

# Set the size of the plot
plt.figure(figsize=(12, 6))

# Plot the sliced predicted probabilities with the updated sample indices
plt.plot(sample_indices, y_pred_probs_slice)
plt.xlabel('10 Minute Intervals', fontname='Times New Roman', fontsize=12)
plt.ylabel('Predicted Probability', fontname='Times New Roman', fontsize=12)
# plt.title(f'Predicted Probabilities for Test 1 Bearing 3 (Sample {i} to End)', fontname='Times New Roman', fontsize=12)
plt.xticks(fontname='Times New Roman', fontsize=12)
plt.yticks(fontname='Times New Roman', fontsize=12)
plt.savefig('Test_1_Bearing_3_Probs_Zoomed.png', format='png', dpi = 600)
plt.show()

# %%
# Predict classes
y_pred_probs = model.predict(X_test_b4)
# Out:
# 68/68 [==============================] - 15s 213ms/step

# %%
# Create a list of sample indices from 0 to the end
index = list(range(len(y_pred_probs)))

# Set the size of the plot
plt.figure(figsize=(12, 6))

# Plot the predicted probabilities
plt.plot(index, y_pred_probs)
plt.xlabel('10 Minute Intervals', fontname='Times New Roman', fontsize=12)
plt.ylabel('Predicted Probability', fontname='Times New Roman', fontsize=12)
# plt.title('Predicted Probabilities for Test 1 Bearing 4', fontname='Times New Roman', fontsize=12)
plt.xticks(fontname='Times New Roman', fontsize=12)
plt.yticks(fontname='Times New Roman', fontsize=12)
plt.savefig('Test_1_Bearing_4_Probs.png', format='png', dpi = 600)
plt.show()

# y_pred_classes = (y_pred_probs > 0.5).astype(int).flatten()

# # Generate classification report
# report = classification_report(y_test, y_pred_classes)

# print(report)# Predict classes

# %%
i = 2000

# Slice the predicted probabilities from the 600th sample to the end
y_pred_probs_slice = y_pred_probs[i:]

# Create a list of sample indices from 600 to the end
sample_indices = list(range(i, len(y_pred_probs)))

# Set the size of the plot
plt.figure(figsize=(12, 6))

# Plot the sliced predicted probabilities with the updated sample indices
plt.plot(sample_indices, y_pred_probs_slice)
plt.xlabel('10 Minute Intervals', fontname='Times New Roman', fontsize=12)
plt.ylabel('Predicted Probability', fontname='Times New Roman', fontsize=12)
# plt.title(f'Predicted Probabilities for Test 1 Bearing 4 (Sample {i} to End)', fontname='Times New Roman', fontsize=12)
plt.xticks(fontname='Times New Roman', fontsize=12)
plt.yticks(fontname='Times New Roman', fontsize=12)
plt.savefig('Test_1_Bearing_4_Probs_Zoomed.png', format='png', dpi = 600)
plt.show()

# %%
# # Generate some random indices from test data
# random_indices = np.random.choice(X_test[0].shape[0], 25, replace=False)

# fig, axes = plt.subplots(5, 5, figsize=(10, 10))

# for i, ax in enumerate(axes.flat):
#     # For the sake of the example, let's assume test_images are grayscale 2D arrays. 
#     # If they are RGB, remove cmap="gray" from imshow
#     ax.imshow(X_test[0][random_indices[i]], cmap="gray")
    
#     # Set the title to show actual and predicted labels
#     actual_label = y_test[random_indices[i]]
#     predicted_label = y_pred_classes[random_indices[i]]
#     ax.set_title(f"True: {actual_label}\nPred: {predicted_label}", fontsize = 8)
    
#     # Remove axis ticks
#     ax.axis('off')

# plt.tight_layout()
# plt.show()
